# %%
from dotenv import load_dotenv
load_dotenv()

import os
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

# %%
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# llama-3.1-8b-instant
# Yes, you can join the course now. However, if you want to receive a certificate, you need to submit your project while we're still accepting submissions.

# %%
from rag_helper import RAGBase

assistant = RAGBase(
    index=index,
    llm_client=openai_client
)

print(assistant.model)
# Out:
# gpt-5.4-mini

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions=custom_instructions,
)

# %%
assistant.rag("How do I get a certificate?")
assistant.rag("Can I still join the course after it started?")
# Out:
# llama-3.1-8b-instant
# llama-3.1-8b-instant
# 'To determine if you can still join the course after it started, let\'s analyze the information from the context:\n\n1. In the first "General Course-Related Questions" section, it states, "Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions." This implies that submitting a project during an ongoing course could lead to receiving a certificate as long as you submit in time.\n\n2. The next relevant section mentions that missing homework might not affect a certificate since "homework isn\'t mandatory, only passing the Capstone project is." \n\n3. However, in the section stating, "Certificate: Can I follow the course in a self-paced mode and get a certificate?" it explains that you can only get a certificate if "you finish the course with a \'live\' cohort." This means you\'re required to join a live cohort to participate in the course for a certificate.\n\n4. Lastly, another general question indicates that if you can still submit homework even after the deadline has passed as long as the submission form is still open.\n\nFrom these points, it appears that while you can join the course after it started and still submit your project for a certificate, it does require joining a live cohort and the submission must meet the stated conditions. The key here is being part of a live cohort, thus enabling participation and the opportunity to receive a certificate.'
